# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('zomato.csv')

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.isna().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
# url                            51717 non-null object
# address                        51717 non-null object
# name                           51717 non-null object
# online_order                   51717 non-null object
# book_table                     51717 non-null object
# rate                           43942 non-null object
# votes                          51717 non-null int64
# phone                          50509 non-null object
# location                       51696 non-null object
# rest_type                      51490 non-null object
# dish_liked                     23639 non-null object
# cuisines                       51672 non-null object
# approx_cost(for two people)    51371 non-null object
# reviews_list                   51717 non-null object
# menu_item                      51717 non-null object
# listed_in(type)                51717 non-null object
# ...

# %%
# Online delivery restaruant
df['online_order'].value_counts()
# Out:
# Yes    30444
# No     21273
# Name: online_order, dtype: int64

# %%
df['location'].unique()
# Out:
# array(['Banashankari', 'Basavanagudi', 'Mysore Road', 'Jayanagar',
#        'Kumaraswamy Layout', 'Rajarajeshwari Nagar', 'Vijay Nagar',
#        'Uttarahalli', 'JP Nagar', 'South Bangalore', 'City Market',
#        'Nagarbhavi', 'Bannerghatta Road', 'BTM', 'Kanakapura Road',
#        'Bommanahalli', nan, 'CV Raman Nagar', 'Electronic City', 'HSR',
#        'Marathahalli', 'Sarjapur Road', 'Wilson Garden', 'Shanti Nagar',
#        'Koramangala 5th Block', 'Koramangala 8th Block', 'Richmond Road',
#        'Koramangala 7th Block', 'Jalahalli', 'Koramangala 4th Block',
#        'Bellandur', 'Whitefield', 'East Bangalore', 'Old Airport Road',
#        'Indiranagar', 'Koramangala 1st Block', 'Frazer Town', 'RT Nagar',
#        'MG Road', 'Brigade Road', 'Lavelle Road', 'Church Street',
#        'Ulsoor', 'Residency Road', 'Shivajinagar', 'Infantry Road',
#        'St. Marks Road', 'Cunningham Road', 'Race Course Road',
# ...

# %%
import seaborn as sns
plt.figure(figsize=(10, 7))
sns.set_style('darkgrid')
chains= df['name'].value_counts()[:20]
#online= df['']
sns.barplot(x= chains, y = chains.index, palette= 'dark')
sns.despine()
plt.title('Top 20 restaurant chains in Bangaluru')
plt.xlabel('Number of outlets')
plt.ylabel('Name of Restaurants')
# Out:
# Text(0, 0.5, 'Name of Restaurants')

# %% [markdown]
# ## Cafee Cofee Day has the most number of outlets in the city of bangaluru. McDonald's is on the 17th number according to number of outlets.

# %%
df['rate']=df['rate'].astype(str)
df['rate']=df['rate'].apply(lambda x:x.replace('/5',''))

# %%
df['rate'][:5]
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# 3    3.7
# 4    3.8
# Name: rate, dtype: object

# %%
sns.countplot(x='book_table', data=df)

# %%
print("Number of restaurents with table booking facility")
df['book_table'].value_counts()
# Out:
# Number of restaurents with table booking facility
# No     45268
# Yes     6449
# Name: book_table, dtype: int64

# %%
plt.figure(figsize=(10, 7))
sns.countplot(x='book_table', data=df, hue='listed_in(type)')
plt.title('Type of restaurent providing table booking facilities')
# Out:
# Text(0.5, 1.0, 'Type of restaurent providing table booking facilities')

# %%
df.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
# Replacing restaurents with there ratings given as new to NAN and dopping them finally
df['rate']=df['rate'].replace('NEW',np.NAN)
df['rate']=df['rate'].replace('-',np.NAN)
df.dropna(how='any',inplace=True)

# %%
df['rate']=df.loc[:,'rate'].replace('[ ]','',regex=True)
df['rate']=df['rate'].astype(str)
df['rate']=df['rate'].apply(lambda r:r.replace('/5',''))
df['rate']=df['rate'].apply(lambda r:float(r))

# %%
# Number of restaurents with rating b/w 1.5 and 2
((df.rate>=4.5)&(df.rate<=5)).sum()
# Out:
# 1212

# %%
df.dtypes
# Out:
# url                             object
# address                         object
# name                            object
# online_order                    object
# book_table                      object
# rate                           float64
# votes                            int64
# phone                           object
# location                        object
# rest_type                       object
# dish_liked                      object
# cuisines                        object
# approx_cost(for two people)     object
# reviews_list                    object
# menu_item                       object
# listed_in(type)                 object
# listed_in(city)                 object
# dtype: object

# %%
slices=[((df.rate>=1.5) & (df.rate<2)).sum(),
        ((df.rate>=2) & (df.rate<2.5)).sum(),
        ((df.rate>=2.5) & (df.rate<3)).sum(),
        ((df.rate>=3.0) & (df.rate<3.5)).sum(),
        ((df.rate>=3.5) & (df.rate<4)).sum(),
        ((df.rate>=4) & (df.rate<4.5)).sum(),
        ((df.rate>=4.5) & (df.rate<5)).sum()
       ]
labels=['1.5-2','2-2.5','2.5-3','3-3.5','3.5-4','4-4.5','4.5-5']
colors = ['Red','blue','Green','black','orange','pink']
explode=[0.5,0,0,0.5,0,0,0]
plt.pie(slices,colors=colors, labels=labels, autopct='%1.0f%%', explode=explode)
fig = plt.gcf()
plt.title("Percentage of Restaurants according to their ratings")

fig.set_size_inches(10,10)
plt.show()

# %%
df[(df['rate']>=1.5) & (df['rate']<=2)].count()['name']
# Out:
# 16

# %%
# Analysis of Restaurants based on their online order and how rating is related to it
#ANALYSIS OF RESTAURENTS BASED ON THEIR LOCATION

# %%
df.head(20)
# Out:
#                                                   url  \
# 0   https://www.zomato.com/bangalore/jalsa-banasha...
# 1   https://www.zomato.com/bangalore/spice-elephan...
# 2   https://www.zomato.com/SanchurroBangalore?cont...
# 3   https://www.zomato.com/bangalore/addhuri-udupi...
# 4   https://www.zomato.com/bangalore/grand-village...
# 5   https://www.zomato.com/bangalore/timepass-dinn...
# 7   https://www.zomato.com/bangalore/onesta-banash...
# 8   https://www.zomato.com/bangalore/penthouse-caf...
# 9   https://www.zomato.com/bangalore/smacznego-ban...
# 10  https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 11  https://www.zomato.com/bangalore/cafe-shuffle-...
# 12  https://www.zomato.com/bangalore/the-coffee-sh...
# 13  https://www.zomato.com/bangalore/caf-eleven-ba...
# 14  https://www.zomato.com/SanchurroBangalore?cont...
# 15  https://www.zomato.com/bangalore/cafe-vivacity...
# 16  https://www.zomato.com/bangalore/catch-up-ino-...
# ...

# %%
plt.figure(figsize=(10, 7))
sns.countplot(x='online_order', data=df, hue='book_table')

# %%
#Areas having most number of restaurants
df['location'].value_counts().head()
# Out:
# Koramangala 5th Block    1761
# BTM                      1450
# Indiranagar              1334
# HSR                      1155
# Jayanagar                1040
# Name: location, dtype: int64

# %%
plt.plot(df['location'].value_counts().head())

# %%
print(df[df['online_order']=="Yes"]['rate'].mean())
print(df[df['online_order']=="No"]['rate'].mean())
# Online food providing restaurants  have better average rating
# Out:
# 3.8936798183715235
# 3.930226700251887

# %%
# Online food providing restaurants  have better average ranting

# %%
plt.figure(figsize=(10,7))
sns.countplot(x=df['listed_in(type)'])
plt.xlabel("Type of restaurant")
# Out:
# Text(0.5, 0, 'Type of restaurant')

# %%
# It's clear that most of restaurants are delivery and dine-out type.

# %%
df['approx_cost(for two people)']=df['approx_cost(for two people)'].apply(lambda r:r.replace(',',''))
df['approx_cost(for two people)']=df['approx_cost(for two people)'].apply(lambda r:int(r))

# %%
df.head(20)
# Out:
#                                                   url  \
# 0   https://www.zomato.com/bangalore/jalsa-banasha...
# 1   https://www.zomato.com/bangalore/spice-elephan...
# 2   https://www.zomato.com/SanchurroBangalore?cont...
# 3   https://www.zomato.com/bangalore/addhuri-udupi...
# 4   https://www.zomato.com/bangalore/grand-village...
# 5   https://www.zomato.com/bangalore/timepass-dinn...
# 7   https://www.zomato.com/bangalore/onesta-banash...
# 8   https://www.zomato.com/bangalore/penthouse-caf...
# 9   https://www.zomato.com/bangalore/smacznego-ban...
# 10  https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 11  https://www.zomato.com/bangalore/cafe-shuffle-...
# 12  https://www.zomato.com/bangalore/the-coffee-sh...
# 13  https://www.zomato.com/bangalore/caf-eleven-ba...
# 14  https://www.zomato.com/SanchurroBangalore?cont...
# 15  https://www.zomato.com/bangalore/cafe-vivacity...
# 16  https://www.zomato.com/bangalore/catch-up-ino-...
# ...

# %%
# Cheapest restaurant
df[df['approx_cost(for two people)']==df['approx_cost(for two people)'].min()][['name','approx_cost(for two people)']]
# Out:
#                            name  approx_cost(for two people)
# 5270   Srinidhi Sagar Food Line                           40
# 12232  Srinidhi Sagar Food Line                           40
# 14819  Srinidhi Sagar Food Line                           40
# 17773            Srinidhi Sagar                           40
# 18891  Srinidhi Sagar Food Line                           40
# 27091     Srinidhi Sagar Deluxe                           40
# 29785     Srinidhi Sagar Deluxe                           40
# 32485            Srinidhi Sagar                           40

# %%
# Most expensive restaurant
df[df['approx_cost(for two people)']==df['approx_cost(for two people)'].max()][['name','approx_cost(for two people)']]
# Out:
#                                          name  approx_cost(for two people)
# 19139  Le Cirque Signature - The Leela Palace                         6000
# 45618  Le Cirque Signature - The Leela Palace                         6000

# %%
df['location'].nunique()
# Out:
# 88

# %%
locationCount=df['location'].value_counts(ascending=True)

# %%
fig=plt.figure(figsize=(20,40))
locationCount.plot(kind="barh",fontsize=20)
plt.ylabel("Location names",fontsize=50,color="red",fontweight='bold')
plt.title("LOCATION VS RESTAURANT COUNT GRAPH",fontsize=40,color="BLACK")
plt.show()

# %%
# Analysis on food type restaurants....
NorthfoodType=df[df['cuisines'].str.contains('North indian', case=False, regex=True, na=False)]

# %%
NorthfoodType['name'].nunique()
# Out:
# 1534

# %%
SouthfoodType=df[df['cuisines'].str.contains('South indian', case=False, regex=True, na=False)]

# %%
SouthfoodType['name'].nunique()
# Out:
# 522

# %%
ChinesefoodType=df[df['cuisines'].str.contains('Chinese|Momos', case=False, regex=True, na=False)]

# %%
ChinesefoodType['name'].nunique()
# Out:
# 1178

# %%
MexicanfoodType=df[df['cuisines'].str.contains('Mexican', case=False, regex=True, na=False)]

# %%
MexicanfoodType['name'].nunique()
# Out:
# 44

# %%
ItalianfoodType=df[df['cuisines'].str.contains('Italian', case=False, regex=True, na=False)]

# %%
ItalianfoodType['name'].nunique()
# Out:
# 316

# %%
AmericanFoodRestaurants = df[df['cuisines'].str.contains('american|Burger', case=False, regex=True,na=False)]
AmericanFoodRestaurants.head()
# Out:
#                                                    url  \
# 18   https://www.zomato.com/bangalore/t3h-cafe-bana...
# 31   https://www.zomato.com/bangalore/foodiction-1-...
# 42   https://www.zomato.com/bangalore/mcdonalds-ban...
# 55   https://www.zomato.com/bangalore/freshmenu-ban...
# 153  https://www.zomato.com/bangalore/kfc-banashank...
#
#                                                address        name  \
# 18   504, CJ Venkata Das Road, Padmanabhangar, 2nd ...    T3H Cafe
# 31   2/1, 7th Main, Dwarakangar, Hosakeregalli, Ban...  Foodiction
# 42   2466, Bhaskar Grand Tower, 24th Cross, Opposit...  McDonald's
# 55   10, Stavyah Arcade, 3rd Floor 9th Main, Yarab ...   FreshMenu
# 153  1, 80 Feet Road, 6th Block, 3rd Stage, Banasha...         KFC
#
#     online_order book_table  rate  votes                         phone  \
# 18            No         No   3.9     93                +91 8884726600
# 31           Yes         No   2.8    506                +91 9916107070
# ...
